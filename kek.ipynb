# %%
import pandas as pd

# %%
df = pd.read_csv("answers.csv", header=None)
df.sample(10)
# Out:
#                                                     0  1      2
# 0   https://movies.stackexchange.com/questions/779...  0   True  \
# 6   https://movies.stackexchange.com/questions/805...  1  False
# 9   https://movies.stackexchange.com/questions/897...  1  False
# 4   https://movies.stackexchange.com/questions/929...  1  False
# 7   https://movies.stackexchange.com/questions/805...  2  False
# 3   https://movies.stackexchange.com/questions/929...  0   True
# 2   https://movies.stackexchange.com/questions/779...  2  False
# 10  https://movies.stackexchange.com/questions/677...  0   True
# 5   https://movies.stackexchange.com/questions/805...  0   True
# 1   https://movies.stackexchange.com/questions/779...  1  False
#
#                                                     3                 4
# 0   I recall hearing once that there was a differe...             dvaeg  \
# 6   The director of Blade Runner 2049, Denis Ville...          Paulie_D
# ...
